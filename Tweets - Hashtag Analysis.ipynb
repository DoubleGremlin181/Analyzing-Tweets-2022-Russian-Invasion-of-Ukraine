# %%
import pandas as pd
import numpy as np

from collections import Counter

import statsmodels.api as sm

from tqdm.auto import tqdm
tqdm.pandas()

# %% [markdown]
# ## Reading the data

# %%
df = pd.read_csv('Tweets - Sentiment Analysis (RoBERTa) Raw Values.csv', lineterminator='\n')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3735462 entries, 0 to 3735461
# Data columns (total 12 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   tweetid   int64
#  1   text      object
#  2   hashtags  object
#  3   language  object
#  4   date      object
#  5   negative  float64
#  6   neutral   float64
#  7   positive  float64
#  8   anger     float64
#  9   joy       float64
#  10  optimism  float64
#  11  sadness   float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 342.0+ MB

# %%
df.head()
# Out:
#                tweetid                                               text  \
# 0  1499174584720969730  Map situation in #Ukraine after the seventh da...
# 1  1499174584976826368  #Ukraine: Let's just say it's not just the TB-...
# 2  1499174585073242116  ⚡️The SWIFT company confirmed that it will dis...
# 3  1499174585987600384  #Ukraine: Ukrainian forces recovered a Eniks E...
# 4  1499174586159665155  Volunteers needed for a rapid-response #DH #Di...
#
#                                           hashtags language   date  negative  \
# 0             ['Ukraine', 'RussiaUkraineConflict']       en  MAR03  0.237624
# 1                                      ['Ukraine']       en  MAR03  0.947360
# 2                                ['EU', 'Russian']       en  MAR03 -0.295086
# 3                                      ['Ukraine']       en  MAR03 -1.926291
# 4  ['DH', 'DigitalHumanities', 'CulturalHeritage']       en  MAR03 -1.135949
#
#     neutral  positive     anger       joy  optimism   sadness
# 0  1.357651 -1.783151  1.320624 -1.717873 -0.575291  1.707901
# 1  0.889939 -2.091296  1.598669 -0.535707  0.341185 -0.105763
# 2  1.447142 -1.220792  2.702571 -1.684210 -0.772874  0.606500
# 3  1.267447  0.810379  1.197331  0.001189  0.045890  0.067511
# 4  1.682476 -0.762521  0.115792 -0.286950  0.583140  0.516610

# %%
df['hashtags'] = df.hashtags.progress_apply(eval)
# Out:
#   0%|          | 0/3735462 [00:00<?, ?it/s]

# %% [markdown]
# ## Getting popular hashtags

# %%
hashtags = df.hashtags.to_list()
hashtags = [j for i in hashtags for j in i]  # Flattening

# %%
hashtag_occurances = Counter(hashtags)
hashtag_occurances = Counter({k: c for k, c in hashtag_occurances.items() if c >= 500})  # Only keeping popular hashtags

# %%
print("Top 10 hashtags")
hashtag_occurances.most_common(10)
# Out:
# Top 10 hashtags
# [('Ukraine', 1361248),
#  ('Russia', 652633),
#  ('Putin', 414755),
#  ('StopPutin', 201149),
#  ('SafeAirliftUkraine', 159124),
#  ('Russian', 152752),
#  ('UkraineRussianWar', 147350),
#  ('UkraineRussiaWar', 127101),
#  ('StandWithUkraine', 126355),
#  ('Kyiv', 109992)]

# %%
popular_hashtags = list(dict(hashtag_occurances.most_common(40)).keys())

# %% [markdown]
# ## Transforming the dataframe

# %%
df.columns
# Out:
# Index(['tweetid', 'text', 'hashtags', 'language', 'date', 'negative',
#        'neutral', 'positive', 'anger', 'joy', 'optimism', 'sadness'],
#       dtype='object')

# %%
df = df.explode('hashtags')
df = df[['date', 'hashtags', 'negative', 'neutral', 'positive', 'anger', 'joy', 'optimism', 'sadness']]
df.rename(columns={"hashtags": "hashtag"}, inplace=True)
df = df[df.hashtag.isin(popular_hashtags)]
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#           date             hashtag  negative   neutral  positive     anger  \
# 0        MAR03             Ukraine  0.237624  1.357651 -1.783151  1.320624
# 1        MAR03             Ukraine  0.947360  0.889939 -2.091296  1.598669
# 2        MAR03                  EU -0.295086  1.447142 -1.220792  2.702571
# 3        MAR03             Russian -0.295086  1.447142 -1.220792  2.702571
# 4        MAR03             Ukraine -1.926291  1.267447  0.810379  1.197331
# ...        ...                 ...       ...       ...       ...       ...
# 4765915  MAR05                NATO  0.844373  0.767706 -1.969419  2.737618
# 4765916  MAR05             Ukraine  1.888199  0.310074 -2.671582  2.163848
# 4765917  MAR05               Putin  1.888199  0.310074 -2.671582  2.163848
# 4765918  MAR05  SafeAirliftUkraine  1.888199  0.310074 -2.671582  2.163848
# 4765919  MAR05             Ukraine -0.767866  1.070801 -0.351321  0.298714
#
#               joy  optimism   sadness
# 0       -1.717873 -0.575291  1.707901
# 1       -0.535707  0.341185 -0.105763
# 2       -1.684210 -0.772874  0.606500
# 3       -1.684210 -0.772874  0.606500
# 4        0.001189  0.045890  0.067511
# ...           ...       ...       ...
# 4765915 -1.661515  0.054990 -0.094986
# 4765916 -2.166087 -0.164755  0.844673
# 4765917 -2.166087 -0.164755  0.844673
# 4765918 -2.166087 -0.164755  0.844673
# 4765919 -0.168255 -0.014217  0.867072
#
# [4765920 rows x 9 columns]

# %%
df = pd.get_dummies(df,columns=['hashtag'],drop_first=True)

# %% [markdown]
# ## Getting the top hashtags for each sentiment

# %%
sentiment_cols = ['negative', 'neutral', 'positive', 'anger', 'joy', 'optimism', 'sadness']
hashtag_cols = [col for col in df if col.startswith('hashtag')]

# %%
top_hashtags = {}
for sentiment in tqdm(sentiment_cols):
    print("**********************")
    print(f"Analyzing {sentiment}")
    result = sm.OLS(df[sentiment], df[hashtag_cols]).fit()
    print(result.summary())
    top_hashtags[sentiment] = result.params.sort_values(ascending=False).head(5).to_dict()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# **********************
# Analyzing negative
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               negative   R-squared (uncentered):                   0.273
# Model:                            OLS   Adj. R-squared (uncentered):              0.273
# Method:                 Least Squares   F-statistic:                          4.599e+04
# Date:                Thu, 17 Mar 2022   Prob (F-statistic):                        0.00
# Time:                        17:59:45   Log-Likelihood:                     -8.0505e+06
# No. Observations:             4765920   AIC:                                  1.610e+07
# Df Residuals:                 4765881   BIC:                                  1.610e+07
# Df Model:                          39
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# hashtag_BREAKING                0.7484      0.008     88.370      0.000       0.732       0.765
# hashtag_China                   0.3194      0.008     37.807      0.000       0.303       0.336
# hashtag_EU                     -0.0326      0.008     -4.204      0.000      -0.048      -0.017
# hashtag_Europe                  0.6621      0.008     79.815      0.000       0.646       0.678
# hashtag_Kharkiv                 1.0138      0.005    192.564      0.000       1.004       1.024
# hashtag_Kyiv                    0.4079      0.004    103.241      0.000       0.400       0.416
# hashtag_Mariupol                1.8757      0.006    329.385      0.000       1.865       1.887
# hashtag_NATO                    0.5315      0.004    120.871      0.000       0.523       0.540
# hashtag_Putin                   1.2325      0.002    605.767      0.000       1.228       1.236
# hashtag_Russia                  0.7925      0.002    488.591      0.000       0.789       0.796
# hashtag_RussiaUkraine           0.6399      0.005    119.181      0.000       0.629       0.650
# hashtag_RussiaUkraineWar        0.8111      0.006    147.225      0.000       0.800       0.822
# hashtag_Russian                 1.0711      0.003    319.485      0.000       1.065       1.078
# hashtag_RussianUkrainianWar     0.8406      0.005    181.614      0.000       0.832       0.850
# hashtag_SafeAirliftUkraine      1.4387      0.003    437.985      0.000       1.432       1.445
# hashtag_SlavaUkraini           -0.4402      0.008    -53.028      0.000      -0.456      -0.424
# hashtag_StandWithUkraine       -0.1311      0.004    -35.570      0.000      -0.138      -0.124
# hashtag_StandWithUkraine️       0.0111      0.008      1.404      0.160      -0.004       0.027
# hashtag_StopPutin               1.2841      0.003    439.519      0.000       1.278       1.290
# hashtag_StopPutinNOW            0.8832      0.006    144.843      0.000       0.871       0.895
# hashtag_StopRussia              0.8979      0.005    175.606      0.000       0.888       0.908
# hashtag_UKRAINE                 0.8833      0.007    131.262      0.000       0.870       0.896
# hashtag_US                      0.7462      0.008     90.050      0.000       0.730       0.762
# hashtag_Ukraine                 0.3542      0.001    315.408      0.000       0.352       0.356
# hashtag_UkraineRussia           0.7094      0.008     87.048      0.000       0.693       0.725
# hashtag_UkraineRussiaWar        0.7322      0.004    199.219      0.000       0.725       0.739
# hashtag_UkraineRussianWar       0.9197      0.003    269.428      0.000       0.913       0.926
# hashtag_UkraineUnderAttack      1.2719      0.005    255.278      0.000       1.262       1.282
# hashtag_UkraineUnderAttaсk      0.7062      0.008     91.001      0.000       0.691       0.721
# hashtag_UkraineWar              0.7553      0.005    137.999      0.000       0.745       0.766
# hashtag_Ukraine️                0.2255      0.006     39.793      0.000       0.214       0.237
# hashtag_Ukrainian               0.5795      0.006    104.209      0.000       0.569       0.590
# hashtag_Ukriane                 0.4857      0.008     60.025      0.000       0.470       0.502
# hashtag_Zelensky                0.2215      0.007     30.521      0.000       0.207       0.236
# hashtag_Zelenskyy              -0.1206      0.009    -13.959      0.000      -0.137      -0.104
# hashtag_putin                   0.9803      0.008    120.548      0.000       0.964       0.996
# hashtag_russia                  0.6200      0.007     90.531      0.000       0.607       0.633
# hashtag_ukraine                 0.1634      0.005     32.385      0.000       0.153       0.173
# hashtag_war                     0.7532      0.007    106.978      0.000       0.739       0.767
# ==============================================================================
# Omnibus:                   300755.637   Durbin-Watson:                   1.401
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           360999.594
# Skew:                          -0.669   Prob(JB):                         0.00
# Kurtosis:                       3.168   Cond. No.                         7.69
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# **********************
# Analyzing neutral
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                neutral   R-squared (uncentered):                   0.686
# Model:                            OLS   Adj. R-squared (uncentered):              0.686
# Method:                 Least Squares   F-statistic:                          2.676e+05
# Date:                Thu, 17 Mar 2022   Prob (F-statistic):                        0.00
# Time:                        17:59:56   Log-Likelihood:                     -2.9141e+06
# No. Observations:             4765920   AIC:                                  5.828e+06
# Df Residuals:                 4765881   BIC:                                  5.829e+06
# Df Model:                          39
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# hashtag_BREAK
# hashtag_Ukriane                 1.6190      0.007    218.012      0.000       1.604       1.634
# hashtag_Zelensky                1.3530      0.007    203.137      0.000       1.340       1.366
# hashtag_Zelenskyy               1.0523      0.008    132.746      0.000       1.037       1.068
# hashtag_putin                   2.0805      0.007    278.760      0.000       2.066       2.095
# hashtag_russia                  1.7907      0.006    284.905      0.000       1.778       1.803
# hashtag_ukraine                 1.2454      0.005    268.962      0.000       1.236       1.254
# hashtag_war                     1.8735      0.006    289.908      0.000       1.861       1.886
# ==============================================================================
# Omnibus:                   131707.005   Durbin-Watson:                   1.378
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           116216.400
# Skew:                          -0.325   Prob(JB):                         0.00
# Kurtosis:                       2.596   Cond. No.                         7.69
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# **********************
# Analyzing joy
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    joy   R-squared (uncentered):                   0.459
# Model:                            OLS   Adj. R-squared (uncentered):              0.459
# Method:                 Least Squares   F-statistic:                          1.038e+05
# Date:                Thu, 17 Mar 2022   Prob (F-statistic):                        0.00
# Time:                        18:00:30   Log-Likelihood:                     -7.3337e+06
# No. Observations:             4765920   AIC:                                  1.467e+07
# Df Residuals:                 4765881   BIC:                                  1.467e+07
# Df Model:                          39
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# hashtag_BREAKING               -0.9189      0.007   -126.112      0.000      -0.933      -0.905
# hashtag_China                  -1.0549      0.007   -145.108      0.000      -1.069      -1.041
# hashtag_EU                     -0.7825      0.007   -117.220      0.000      -0.796      -0.769
# hashtag_Europe                 -1.3419      0.007   -188.018      0.000      -1.356      -1.328
# hashtag_Kharkiv                -0.8119      0.005   -179.240      0.000      -0.821      -0.803
# hashtag_Kyiv                   -0.4968      0.003   -146.164      0.000      -0.503      -0.490
# hashtag_Mariupol               -1.3539      0.005   -276.336      0.000      -1.364      -1.344
# hashtag_NATO                   -0.9569      0.004   -252.916      0.000      -0.964      -0.950
# hashtag_Putin                  -1.4397      0.002   -822.459      0.000      -1.443      -1.436
# hashtag_Russia                 -0.9626      0.001   -689.818      0.000      -0.965      -0.960
# hashtag_RussiaUkraine          -0.7177      0.005   -155.383      0.000      -0.727      -0.709
# hashtag_RussiaUkraineWar       -0.9064      0.005   -191.237      0.000      -0.916      -0.897
# hashtag_Russian                -1.1126      0.003   -385.735      0.000      -1.118      -1.107
# hashtag_RussianUkrainianWar    -0.9390      0.004   -235.805      0.000      -0.947      -0.931
# hashtag_SafeAirliftUkraine     -2.1444      0.003   -758.796      0.000      -2.150      -2.139
# hashtag_SlavaUkraini            0.0562      0.007      7.864      0.000       0.042       0.070
# hashtag_StandWithUkraine       -0.7165      0.003   -225.910      0.000      -0.723      -0.710
# hashtag_StandWithUkraine️      -0.7680      0.007   -112.962      0.000      -0.781      -0.755
# hashtag_StopPutin              -1.9977      0.003   -794.757      0.000      -2.003      -1.993
# hashtag_StopPutinNOW           -1.3835      0.005   -263.711      0.000      -1.394      -1.373
# hashtag_StopRussia             -1.5875      0.004   -360.868      0.000      -1.596      -1.579
# hashtag_UKRAINE                -1.4554      0.006   -251.377      0.000      -1.467      -1.444
# hashtag_US                     -1.2322      0.007   -172.834      0.000      -1.246      -1.218
# hashtag_Ukraine                -0.6169      0.001   -638.468      0.000      -0.619      -0.615
# hashtag_UkraineRussia          -0.7026      0.007   -100.200      0.000      -0.716      -0.689
# hashtag_UkraineRussiaWar       -0.7535      0.003   -238.285      0.000      -0.760      -0.747
# hashtag_UkraineRussianWar      -0.8643      0.003   -294.294      0.000      -0.870      -0.859
# hashtag_UkraineUnderAttack     -1.0344      0.004   -241.315      0.000      -1.043      -1.026
# hashtag_UkraineUnderAttaсk     -0.8188      0.007   -122.632      0.000      -0.832      -0.806
# hashtag_UkraineWar             -0.8551      0.005   -181.586      0.000      -0.864      -0.846
# hashtag_Ukraine️               -0.5408      0.005   -110.908      0.000      -0.550      -0.531
# hashtag_Ukrainian              -0.6728      0.005   -140.618      0.000      -0.682      -0.663
# hashtag_Ukriane                -0.6847      0.007    -98.355      0.000      -0.698      -0.671
# hashtag_Zelensky               -0.2766      0.006    -44.304      0.000      -0.289      -0.264
# hashtag_Zelenskyy               0.0171      0.007      2.304      0.021       0.003       0.032
# hashtag_putin                  -0.8904      0.007   -127.269      0.000      -0.904      -0.877
# hashtag_russia                 -0.6801      0.006   -115.430      0.000      -0.692      -0.669
# hashtag_ukraine                -0.5613      0.004   -129.324      0.000      -0.570      -0.553
# hashtag_war                    -1.0455      0.006   -172.597      0.000      -1.057      -1.034
# ==============================================================================
# Omnibus:                   977010.901   Durbin-Watson:                   1.418
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1807691.298
# Skew:                           1.290   Prob(JB):                         0.00
# Kurtosis:                       4.565   Cond. No.                         7.69
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# **********************
# Analyzing optimism
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               optimism   R-squared (uncentered):                   0.090
# Model:                            OLS   Adj. R-squared (uncentered):              0.090
# Method:                 Least Squares   F-statistic:                          1.209e+04
# Date:                Thu, 17 Mar 2022   Prob (F-statistic):                        0.00
# Time:                        18:00:41   Log-Likelihood:                     -5.6887e+06
# No. Observations:             4765920   AIC:                                  1.138e+07
# Df Residuals:                 4765881   BIC:                                  1.138e+07
# Df Model:                          39
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# hashtag_BREAKING               -0.5610      0.005   -108.723      0.000      -0.571      -0.551
# hashtag_China                   0.4182      0.005     81.241      0.000       0.408       0.428
# hashtag_EU                      0.2994      0.005     63.345      0.000       0.290       0.309
# hashtag_Europe                  0.0032      0.005      0.643      0.520      -0.007       0.013
# hashtag_Kharkiv                -0.4168      0.003   -129.955      0.000      -0.423      -0.411
# hashtag_Kyiv                   -0.1311      0.002    -54.475      0.000      -0.136      -0.126
# hashtag_Mariupol               -0.7178      0.003   -206.904      0.000      -0.725      -0.711
# hashtag_NATO                    0.1687      0.003     62.958      0.000       0.163       0.174
# hashtag_Putin                   0.0183      0.001     14.751      0.000       0.016       0.021
# hashtag_Russia                 -0.1988      0.001   -201.140      0.000      -0.201      -0.197
# hashtag_RussiaUkraine          -0.2209      0.003    -67.537      0.000      -0.227      -0.214
# hashtag_RussiaUkraineWar       -0.3078      0.003    -91.700      0.000      -0.314      -0.301
# hashtag_Russian                -0.3712      0.002   -181.751      0.000      -0.375      -0.367
# hashtag_RussianUkrainianWar    -0.2685      0.003    -95.226      0.000      -0.274      -0.263
# hashtag_SafeAirliftUkraine      0.2433      0.002    121.576      0.000       0.239       0.247
# hashtag_SlavaUkraini            0.2150      0.005     42.510      0.000       0.205       0.225
# hashtag_StandWithUkraine        0.6170      0.002    274.756      0.000       0.613       0.621
# hashtag_StandWithUkraine️       0.5015      0.005    104.169      0.000       0.492       0.511
# hashtag_StopPutin               0.1298      0.002     72.911      0.000       0.126       0.133
# hashtag_StopPutinNOW            0.1482      0.004     39.899      0.000       0.141       0.156
# hashtag_StopRussia             -0.1408      0.003    -45.205      0.000      -0.147      -0.135
# hashtag_UKRAINE                -0.3727      0.004    -90.910      0.000      -0.381      -0.365
# hashtag_US                      0.0106      0.005      2.097      0.036       0.001       0.020
# hashtag_Ukraine                 0.0257      0.001     37.520      0.000       0.024       0.027
# hashtag_UkraineRussia          -0.4220      0.005    -84.999      0.000      -0.432      -0.412
# hashtag_UkraineRussiaWar       -0.2971      0.002   -132.688      0.000      -0.301      -0.293
# hashtag_UkraineRussianWar      -0.4330      0.002   -208.237      0.000      -0.437      -0.429
# hashtag_UkraineUnderAttack     -0.7778      0.003   -256.235      0.000      -0.784      -0.772
# hashtag_UkraineUnderAttaсk     -0.2782      0.005    -58.848      0.000      -0.287      -0.269
# hashtag_UkraineWar             -0.3272      0.003    -98.135      0.000      -0.334      -0.321
# hashtag_Ukraine️                0.0183      0.003      5.309      0.000       0.012       0.025
# hashtag_Ukrainian              -0.1743      0.003    -51.454      0.000      -0.181      -0.168
# hashtag_Ukriane                -0.0463      0.005     -9.391      0.000      -0.056      -0.037
# hashtag_Zelensky                0.1022      0.004     23.106      0.000       0.093       0.111
# hashtag_Zelenskyy               0.1406      0.005     26.716      0.000       0.130       0.151
# hashtag_putin                  -0.2933      0.005    -59.208      0.000      -0.303      -0.284
# hashtag_russia                 -0.3203      0.004    -76.764      0.000      -0.328      -0.312
# hashtag_ukraine                -0.1898      0.003    -61.740      0.000      -0.196      -0.184
# hashtag_war                    -0.1357      0.004    -31.635      0.000      -0.144      -0.127
# ==============================================================================
# Omnibus:                   385112.926   Durbin-Watson:                   1.322
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           486568.541
# Skew:                           0.749   Prob(JB):                         0.00
# Kurtosis:                       3.452   Cond. No.                         7.69
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# **********************
# Analyzing sadness
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                sadness   R-squared (uncentered):                   0.122
# Model:                            OLS   Adj. R-squared (uncentered):              0.122
# Method:                 Least Squares   F-statistic:                          1.691e+04
# Date:                Thu, 17 Mar 2022   Prob (F-statistic):                        0.00
# Time:                        18:00:52   Log-Likelihood:                     -6.1267e+06
# No. Observations:             4765920   AIC:                                  1.225e+07
# Df Residuals:                 4765881   BIC:                                  1.225e+07
# Df Model:                          39
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# hashtag_BREAKING                0.5920      0.006    104.664      0.000       0.581       0.603
# hashtag_China                   0.0208      0.006      3.686      0.000       0.010       0.032
# hashtag_EU                     -0.0717      0.005    -13.835      0.000      -0.082      -0.062
# hashtag_Europe                  0.1861      0.006     33.583      0.000       0.175       0.197
# hashtag_Kharkiv                 0.5038      0.004    143.265      0.000       0.497       0.511
# hashtag_Kyiv                    0.2368      0.003     89.734      0.000       0.232       0.242
# hashtag_Mariupol                1.0005      0.004    263.054      0.000       0.993       1.008
# hashtag_NATO                   -0.0334      0.003    -11.376      0.000      -0.039      -0.028
# hashtag_Putin                   0.3058      0.001    225.062      0.000       0.303       0.308
# hashtag_Russia                  0.2775      0.001    256.156      0.000       0.275       0.280
# hashtag_RussiaUkraine           0.0781      0.004     21.778      0.000       0.071       0.085
# hashtag_RussiaUkraineWar        0.1813      0.004     49.265      0.000       0.174       0.188
# hashtag_Russian                 0.4397      0.002    196.362      0.000       0.435       0.444
# hashtag_RussianUkrainianWar     0.0609      0.003     19.708      0.000       0.055       0.067
# hashtag_SafeAirliftUkraine      0.7927      0.002    361.342      0.000       0.788       0.797
# hashtag_SlavaUkraini           -0.3523      0.006    -63.555      0.000      -0.363      -0.341
# hashtag_StandWithUkraine       -0.2331      0.002    -94.695      0.000      -0.238      -0.228
# hashtag_StandWithUkraine️      -0.2323      0.005    -44.007      0.000      -0.243      -0.222
# hashtag_StopPutin               0.4679      0.002    239.786      0.000       0.464       0.472
# hashtag_StopPutinNOW            0.0589      0.004     14.463      0.000       0.051       0.067
# hashtag_StopRussia             -0.2506      0.003    -73.394      0.000      -0.257      -0.244
# hashtag_UKRAINE                -0.4153      0.004    -92.397      0.000      -0.424      -0.406
# hashtag_US                      0.2258      0.006     40.803      0.000       0.215       0.237
# hashtag_Ukraine                 0.2013      0.001    268.442      0.000       0.200       0.203
# hashtag_UkraineRussia           0.2205      0.005     40.510      0.000       0.210       0.231
# hashtag_UkraineRussiaWar        0.1143      0.002     46.551      0.000       0.109       0.119
# hashtag_UkraineRussianWar       0.3987      0.002    174.910      0.000       0.394       0.403
# hashtag_UkraineUnderAttack      0.7452      0.003    223.938      0.000       0.739       0.752
# hashtag_UkraineUnderAttaсk      0.0363      0.005      7.010      0.000       0.026       0.046
# hashtag_UkraineWar              0.1127      0.004     30.838      0.000       0.106       0.120
# hashtag_Ukraine️                0.0558      0.004     14.737      0.000       0.048       0.063
# hashtag_Ukrainian               0.2217      0.004     59.696      0.000       0.214       0.229
# hashtag_Ukriane                 0.0026      0.005      0.478      0.633      -0.008       0.013
# hashtag_Zelensky               -0.2072      0.005    -42.745      0.000      -0.217      -0.198
# hashtag_Zelenskyy              -0.3274      0.006    -56.758      0.000      -0.339      -0.316
# hashtag_putin                   0.0025      0.005      0.457      0.648      -0.008       0.013
# hashtag_russia                  0.0401      0.005      8.766      0.000       0.031       0.049
# hashtag_ukraine                 0.2274      0.003     67.506      0.000       0.221       0.234
# hashtag_war                     0.1619      0.005     34.432      0.000       0.153       0.171
# ==============================================================================
# Omnibus:                   348918.267   Durbin-Watson:                   1.357
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           443515.600
# Skew:                           0.677   Prob(JB):                         0.00
# Kurtosis:                       3.632   Cond. No.                         7.69
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
for sentiment, hashtags in top_hashtags.items():
    print(f"{sentiment}: {[k.split('_')[1] for k,v in list(hashtags.items()) if v > 0]}")
# Out:
# negative: ['Mariupol', 'SafeAirliftUkraine', 'StopPutin', 'UkraineUnderAttack', 'Putin']
# neutral: ['BREAKING', 'EU', 'China', 'US', 'NATO']
# positive: []
# anger: ['UKRAINE', 'StopRussia', 'StopPutin', 'putin', 'RussianUkrainianWar']
# joy: ['SlavaUkraini', 'Zelenskyy']
# optimism: ['StandWithUkraine', 'StandWithUkraine️', 'China', 'EU', 'SafeAirliftUkraine']
# sadness: ['Mariupol', 'SafeAirliftUkraine', 'UkraineUnderAttack', 'BREAKING', 'Kharkiv']
